# %% [markdown]
# # Estándar y Estandarización
#
# En las actividades empresariales, para ofrecer productos y servicios de calidad estable a los clientes, la estandarización se vuelve crucial para controlar eficazmente la variabilidad y asegurar el avance sin errores en el trabajo realizado por cada departamento.

# %%
import os

try:
  os.chdir('../Python/QCKentei4')
except:
  pass

path = os.getcwd()
path
# Out:
# '/Users/takanohiroshi/Library/CloudStorage/OneDrive-YokohamaInternationalExchangeAssociation/Python/QCKentei4'

# %%
from PIL import Image

# %% [markdown]
# ## 06-01 Estandarización / Normalización
#
# Se refiere a la actividad de establecer como estándar aquello que se considera el mejor método para realizar algo (ya sea un objeto o una forma de trabajar), y actuar de acuerdo con dicho estándar.
#
# Un estándar (o norma) es un acuerdo establecido con el propósito de lograr la unificación y la amplificación, de manera que los beneficios o la conveniencia se obtengan de forma equitativa entre las personas u organizaciones relacionadas.

# %% [markdown]
# ## 06-02 Criterios relacionados con el trabajo / Estándares relacionados con las operaciones / Normas relativas a las tareas.Estándares para articulos (especificaciones ) / Normas para productos (especificaciones) / Criterios para bienes (especificaciones)
#
# ### 1. Criterios relacionados con el trabajo / Estándares relacionados con las operaciones / Normas relativas a las tareas.Estándares para articulos (especificaciones ) / Normas para productos (especificaciones) / Criterios para bienes (especificaciones)
#
# * SDCA
# * Estándar interno
#
# ### 2. Estándar interno
#
# 1. Regulación, Disposición, Norma, Reglamento
# 2. Especificación, Estándar, Norma, Pliego de condiciones.
# 3. Estándar
# 4. Procedimiento, Manual
# 5. Especificaciónes técnicas, Pliego de especificaciones, Ficha técnica.

# %% [markdown]
# ## 06-03 Varios estándares / Diversos estándares / Diferentes normas
#
# * Norma internacional / Estándar internacional / Especificación internacionaL
# * Norma regional / Especificaión regional
# * Norma nacional / Especificación nacional / Especificación nacional
# * Norma de asociación / Estándar de organización / Especificación de entidad

# %%
img = Image.open('./Data4/Normas.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=581x415>

# %%
notebook_name = 'QCKentei4-6.ipynb'
notebook_name_html = notebook_name.replace(".ipynb",".html")

# !jupyter nbconvert --to html {notebook_name}
# Out:
# [NbConvertApp] Converting notebook QCKentei4-6.ipynb to html
# [NbConvertApp] Writing 728073 bytes to QCKentei4-6.html

# %%
from IPython.display import display
from PIL import Image
import gdown
import re

def get_file_id(url,out):
    # 正規表現でファイルIDを抽出
    match = re.search(r'/d/([a-zA-Z0-9_-]+)', url)

    if match:
        file_id = match.group(1)
        print("ファイルID:", file_id)
    else:
        print("ファイルIDが見つかりませんでした。")

    url = f"https://drive.google.com/uc?id={file_id}"

    output = out

    gdown.download(url, output, quiet=False)

    img = Image.open(out)
    display(img)

# %%
url= 'https://drive.google.com/file/d/1UNcI0hPYV54DNueuCHPhNPXsQXV7O7al/view?usp=drive_link'
out = './Data4/Normas.png'
get_file_id(url,out)
# Out:
# ファイルID: 1UNcI0hPYV54DNueuCHPhNPXsQXV7O7al
# Downloading...
# From: https://drive.google.com/uc?id=1UNcI0hPYV54DNueuCHPhNPXsQXV7O7al
# To: /Users/takanohiroshi/Library/CloudStorage/OneDrive-YokohamaInternationalExchangeAssociation/Python/QCKentei4/Data4/Normas.png
# 100%|██████████| 38.2k/38.2k [00:00<00:00, 1.13MB/s]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=581x415>
